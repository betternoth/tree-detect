# %% [markdown]
# # YOLO Setup
#
# if necessary, pip install ultralytics

# %%
import numpy
from ultralytics import YOLO

from IPython import display
display.clear_output()
# !yolo checks

from IPython.display import display, Image
import xlwt
import pandas as pd
import torch
import os
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.9 torch-1.13.1+cpu CPU (AMD Ryzen 7 PRO 5850U with Radeon Graphics)
# Setup complete ✅ (16 CPUs, 15.3 GB RAM, 396.8/476.0 GB disk)
#
# OS                  Windows-10-10.0.19045-SP0
# Environment         Windows
# Python              3.10.9
# Install             git
# RAM                 15.31 GB
# CPU                 AMD Ryzen 7 PRO 5850U with Radeon Graphics
# CUDA                None
#
# matplotlib          ✅ 3.4.3
# numpy               ✅ 1.22.4
# opencv-python       ✅ 4.7.0.72
# Pillow              ✅ 10.2.0
# PyYAML              ✅ 6.0
# requests            ✅ 2.28.2
# scipy               ✅ 1.10.1
# torch               ✅ 1.13.1
# torchvision         ✅ 0.14.1
# tqdm                ✅ 4.65.0
# tensorboard         ✅ 2.12.0
# pandas              ✅ 1.5.3
# seaborn             ✅ 0.12.2
# psutil              ✅ 5.9.0
# thop                ✅ 0.1.1-2209072238
# certifi             ✅ 2024.2.2
# sentry-sdk          ✅ 1.16.0

# %%
# Run code first time to download the basic models
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='C:/tree_detect_model/customdog.jpg' visualize=true
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.9 torch-1.13.1+cpu CPU (AMD Ryzen 7 PRO 5850U with Radeon Graphics)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage0_Conv_features.png... (16/16)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage1_Conv_features.png... (32/32)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage2_C2f_features.png... (32/32)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage3_Conv_features.png... (32/64)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage4_C2f_features.png... (32/64)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage5_Conv_features.png... (32/128)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage6_C2f_features.png... (32/128)
# Saving c:\Users\u0153625\runs\detect\predict\customdog\stage7_Conv_features.png... (32/256)
# ...

# %% [markdown]
# # Detect
#
# parameters:
# model = treedetect.pt, conf = confidence [can be adjusted], source = location of test images, imgsz = image size [can be adjusted (increments of 32)], line_thickness = outline of bounding box
#
# a text file will be saved for each image with one row per tree detected

# %%
# !yolo task=detect mode=predict model='C:/tree_detect_model/treedetect.pt' conf=0.25 source='C:/tree_detect_model/testImages' imgsz=1856 line_thickness=10 save=True save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.51  Python-3.9.16 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1043801_ExuGn-XOfL4QdW1NF0QzQA_Date.jpg: 928x1856 4 Trees, 951.8ms
# image 2/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1205601_gQnqt6efsXfrmmlioIuSXQ_Date.jpg: 928x1856 1 Tree, 1270.3ms
# image 3/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1256801_Q-KHP6WB6_exTzFMopNGsw_Date.jpg: 928x1856 13 Trees, 1222.5ms
# image 4/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1358701_HaFohIpZORLBFAkm_psr4A_Date.jpg: 928x1856 26 Trees, 1251.2ms
# image 5/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1503402_LJGGNvxdTw7vCp6dp-lmMg_Date.jpg: 928x1856 (no detections), 1180.1ms
# image 6/1324 F:\StreetviewWorkflow\LeuvenMUN\3TreeDetect\SortedImages\1549501_92BT4pK21UggId7LpHF8uA_Date.jpg: 928x1856 5 Trees, 992.4ms
# ...
